# %%
import psycopg2
import pandas as pd
from string import Template

# %%
# dataname = "small_census_01"
# index = "v1"

# %%
dataname = "small_adult_1"
index = "3"

# %%
# dataname =  "food_small"
# index = "v1"

# %% [markdown]
# ### Connect to db

# %%
conn = psycopg2.connect(host="localhost",
                        database="{}_{}".format(dataname,index), 
                        user="holocleanuser", 
                        password="abcd1234")

# %%
def query_df(q, value = []):
    if len(value) != 0:
        df = pd.read_sql_query(q, conn, params=value)
    else:
        df = pd.read_sql_query(q, conn)
    return df

# %%
def table_lists():
    df = query_df("""SELECT table_name FROM information_schema.tables
       WHERE table_schema = 'public'""")
    return df

# %%
table_lists()
# Out:
#                table_name
# 0          inf_values_idx
# 1           small_adult_1
# 2                dk_cells
# 3             cell_domain
# 4              pos_values
# 5              cell_distr
# 6          inf_values_dom
# 7  small_adult_1_repaired
# 8     small_adult_1_clean

# %%
df = query_df("select * from small_adult_1")

# %%
df.head()
# Out:
#    _tid_  age workclass education  maritalstatus         occupation  \
# 0      0  <18   private      10th  never-married  machine-op-inspct
# 1      1  <18     _nan_      10th  never-married              _nan_
# 2      2  <18   private      11th  never-married              sales
# 3      3  <18   private      10th  never-married              sales
# 4      4  <18     _nan_      11th  never-married              _nan_
#
#     relationship   race     sex hoursperweek        country       income
# 0  not-in-family  white    male           40  united-states  lessthan50k
# 1      own-child  white    male           40  united-states  lessthan50k
# 2      own-child  white  female           25  united-states  lessthan50k
# 3      own-child  white  female        18-21  united-states  lessthan50k
# 4      own-child  white    male           40  united-states  lessthan50k

# %%
# get all attributes 
data = query_df("select * from {}".format(dataname))
attributes = data.columns.values[1:]
attributes
# Out:
# array(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'hoursperweek', 'country', 'income'],
#       dtype=object)

# %% [markdown]
# ### Total Errors

# %%
errors_template = Template('SELECT t1._tid_, t2._attribute_, t1.\"$attr\" as init, t2._value_ as gt '\
                            'FROM $init_table as t1, $grdt_table as t2 '\
                            'WHERE t1._tid_ = t2._tid_ '\
                              'AND t2._attribute_ = \'$attr\' '\
                              'AND t1.\"$attr\" != t2._value_')

# %%
def get_total_errors():
    all_error = []
    for attr in attributes:
        query = errors_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname,
                        attr=attr)
        df = query_df(query)
        all_error.append(df)
    return all_error

# %%
all_error = get_total_errors()

# %%
all_error = pd.concat(all_error, ignore_index=True)

# %%
all_error
# Out:
#     _tid_   _attribute_            init             gt
# 0    1975  relationship       own-child  not-in-family
# 1    2651          race           white          black
# 2    1512           sex            male         female
# 3     605        income    lesjsthan50k    lessthan50k
# 4     609        income     lessthan5k0    lessthan50k
# 5     615        income  lessthan50k***    lessthan50k
# 6     616        income     lessthan5k0    lessthan50k
# 7     619        income    lnessthan50k    lessthan50k
# 8     621        income     lesstahn50k    lessthan50k
# 9     624        income     lesstahn50k    lessthan50k
# 10    628        income      lessthn50k    lessthan50k
# 11    636        income    lessthayn50k    lessthan50k
# 12    650        income    leqssthan50k    lessthan50k
# 13    656        income      lessthan0k    lessthan50k
# 14    657        income  lessthan50k***    lessthan50k
# 15    659        income      lesshan50k    lessthan50k
# 16    669        income  lessthan50k***    lessthan50k
# 17    680        income    lessthan50zk    lessthan50k
# 18    691        income      essthan50k    lessthan50k
# 19    705        income      essthan50k    lessthan50k
# 20    707        income      lesstan50k    lessthan50k
# 21    713        income  lessthan50k***    lessthan50k
# 22    718        income  lessthan50k***    lessthan50k
# 23    723        income     lesstahn50k    lessthan50k
# 24    733        income      lessthn50k    lessthan50k
# 25    734        income      lssthan50k    lessthan50k
# 26    735        income     lesstha5n0k    lessthan50k
# 27    737        income     lessthna50k    lessthan50k
# 28    740        income     lsesthan50k    lessthan50k
# 29    743        income     lessthna50k    lessthan50k
# ..    ...           ...             ...            ...
# 291  2777        income      lessthan0k    lessthan50k
# 292  2781        income     lestshan50k    lessthan50k
# 293  2782        income      lesshan50k    lessthan50k
# 294  2791        income    lekssthan50k    lessthan50k
# 295  2794        income     lsesthan50k    lessthan50k
# 296  2801        income    lesusthan50k    lessthan50k
# 297  2810        income    lessthapn50k    lessthan50k
# 298  2821        income      lessthan0k    lessthan50k
# 299  2824        income     lsesthan50k    lessthan50k
# 300  2826        income    lessothan50k    lessthan50k
# 301  2828        income     lessthan5k0    lessthan50k
# 302  2832        income     elssthan50k    lessthan50k
# 303  2857        income    lessthanb50k    lessthan50k
# 304  2873        income    lessthaan50k    lessthan50k
# 305  2882        income      lssthan50k    lessthan50k
# 306  2885        income    nlessthan50k    lessthan50k
# 307  2898        income    wlessthan50k    lessthan50k
# 308  2905        income     lesstahn50k    lessthan50k
# 309  2910        income      essthan50k    lessthan50k
# 310  2911        income      lesshan50k    lessthan50k
# 311  2913        income  lessthan50k***    lessthan50k
# 312  2915        income    lessthan50gk    lessthan50k
# 313  2935        income     lessthan5k0    lessthan50k
# 314  2945        income      lesstha50k    lessthan50k
# 315  2947        income    lessthan5f0k    lessthan50k
# 316  2950        income    lessjthan50k    lessthan50k
# 317  2951        income      lessthan5k    lessthan50k
# 318  2958        income      essthan50k    lessthan50k
# 319  2971        income      essthan50k    lessthan50k
# 320  2974        income    lwessthan50k    lessthan50k
#
# [321 rows x 4 columns]

# %%
vid_template = Template("SELECT * from cell_domain where attribute = \'$attr\' and _tid_ = \'$tid\'")

# %%
query_df(vid_template.substitute(attr='detailed_household_and_family_stat', tid=632))
# Out:
# Empty DataFrame
# Columns: [_cid_, _tid_, _vid_, attribute, domain, domain_size, fixed, init_index, init_value]
# Index: []

# %%
init_count = all_error.shape[0]
init_count
# Out:
# 321

# %% [markdown]
# ### Total Repair

# %%
query = "SELECT t1._tid_, t1.attribute, t1.init_value as init, t2.rv_value as repair " \
                 "FROM %s as t1, %s as t2 " \
                 "WHERE t1._tid_ = t2._tid_ " \
                   "AND t1.attribute = t2.attribute " \
                   "AND t1.init_value != t2.rv_value"\
                %('cell_domain', 'inf_values_dom')
all_repair = query_df(query)

# %%
all_repair.head()
# Out:
#    _tid_ attribute init repair
# 0      0       age  <18  18-21
# 1      1       age  <18  18-21
# 2      2       age  <18  18-21
# 3      3       age  <18  18-21
# 4      4       age  <18  18-21

# %%
total_repair_init_count = all_repair.shape[0]
total_repair_init_count
# Out:
# 703

# %%
query = "SELECT t1._tid_, t1.attribute, t1.init_value as init, t2.rv_value as repair " \
         "FROM %s as t1, %s as t2, %s as t3 " \
         "WHERE t1._tid_ = t2._tid_ " \
           "AND t1.attribute = t2.attribute " \
           "AND t1.init_value != t2.rv_value " \
           "AND t1._tid_ = t3._tid_ " \
           "AND t1.attribute = t3._attribute_"\
        %('cell_domain', 'inf_values_dom', '%s_clean'%dataname)
repair_gt = query_df(query)

# %%
repair_gt.head(15)
# Out:
#     _tid_ attribute init repair
# 0       0       age  <18  18-21
# 1       1       age  <18  18-21
# 2       2       age  <18  18-21
# 3       3       age  <18  18-21
# 4       4       age  <18  18-21
# 5       5       age  <18  18-21
# 6       6       age  <18  18-21
# 7       7       age  <18  18-21
# 8       8       age  <18  18-21
# 9       9       age  <18  18-21
# 10     10       age  <18  18-21
# 11     11       age  <18  18-21
# 12     12       age  <18  18-21
# 13     13       age  <18  18-21
# 14     14       age  <18  18-21

# %%
repair_gt_init_count = repair_gt.shape[0]
repair_gt_init_count
# Out:
# 703

# %% [markdown]
# ### Correct Repair

# %%
correct_repairs_template = Template('SELECT errors._tid_, errors._attribute_, '\
                            ' errors.init, errors._value_ as gt, repairs.rv_value as repair FROM'\
                            '(SELECT t2._tid_, t2._attribute_, t2._value_, t1.\"$attr\" as init '\
                             'FROM $init_table as t1, $grdt_table as t2 '\
                             'WHERE t1._tid_ = t2._tid_ '\
                               'AND t2._attribute_ = \'$attr\' '\
                               'AND t1.\"$attr\" != t2._value_ ) as errors, $inf_dom as repairs '\
                              'WHERE errors._tid_ = repairs._tid_ '\
                                'AND errors._attribute_ = repairs.attribute '\
                                'AND errors._value_ = repairs.rv_value')

# %%
def get_total_repair():
    all_rp = []
    for attr in attributes:
        query = correct_repairs_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname, 
                                            inf_dom = 'inf_values_dom', attr=attr)
        df = query_df(query)
        all_rp.append(df)
    return all_rp

# %%
all_repair_gt = get_total_repair()

# %%
all_repair_gt = pd.concat(all_repair_gt, ignore_index=True)

# %%
all_repair_gt.head(30)
# Out:
# Empty DataFrame
# Columns: [_tid_, _attribute_, init, gt, repair]
# Index: []

# %%
all_repair_gt.shape[0]
# Out:
# 0

# %% [markdown]
# ### wrong repair correctly detected

# %%
wrong_repairs_template = Template('SELECT errors._tid_, errors._attribute_, '\
                            ' errors.init, errors._value_ as gt, repairs.rv_value as repair FROM'\
                            '(SELECT t2._tid_, t2._attribute_, t2._value_, t1.\"$attr\" as init '\
                             'FROM $init_table as t1, $grdt_table as t2 '\
                             'WHERE t1._tid_ = t2._tid_ '\
                               'AND t2._attribute_ = \'$attr\' '\
                               'AND t1.\"$attr\" != t2._value_ ) as errors, $inf_dom as repairs '\
                              'WHERE errors._tid_ = repairs._tid_ '\
                                'AND errors._attribute_ = repairs.attribute '\
                                'AND errors._value_ <> repairs.rv_value')

# %%
def get_total_wrong_repair():
    all_rp = []
    for attr in attributes:
        query = wrong_repairs_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname, 
                                            inf_dom = 'inf_values_dom', attr=attr)
        df = query_df(query)
        all_rp.append(df)
    return all_rp

# %%
wrong_repair_gt = get_total_wrong_repair()

# %%
wrong_repair_gt = pd.concat(wrong_repair_gt, ignore_index=True)

# %%
wrong_repair_gt
# Out:
#   _tid_   _attribute_       init             gt     repair
# 0  1975  relationship  own-child  not-in-family  own-child
# 1  1512           sex       male         female       male

# %% [markdown]
# ### Detected Errors

# %%
query = "SELECT t1._tid_, t1.init_value as init, t2._value_ as gt " \
        "FROM %s as t1, %s as t2, %s as t3 " \
        "WHERE t1._tid_ = t2._tid_ AND t1._cid_ = t3._cid_ " \
        "AND t1.attribute = t2._attribute_ " \
        "AND t1.init_value != t2._value_" \
        % ('cell_domain', '%s_clean'%dataname, 'dk_cells')

# %%
init_error = query_df(query)

# %%
init_error.shape[0]
# Out:
# 109

# %%
init_error.head(10)
# Out:
#    _tid_            init             gt
# 0   1512            male         female
# 1   1975       own-child  not-in-family
# 2    609     lessthan5k0    lessthan50k
# 3    619    lnessthan50k    lessthan50k
# 4    628      lessthn50k    lessthan50k
# 5    650    leqssthan50k    lessthan50k
# 6    656      lessthan0k    lessthan50k
# 7    657  lessthan50k***    lessthan50k
# 8    734      lssthan50k    lessthan50k
# 9    735     lesstha5n0k    lessthan50k
