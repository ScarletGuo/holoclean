# %%
import psycopg2
import pandas as pd
from string import Template

# %%
# dataname = "small_census_01"
# index = "v1"

# %%
dataname = "small_adult_1"
index = "d3"

# %%
# dataname =  "food_small"
# index = "v1"

# %%
dataname = "adult_1"
index = "1"

# %% [markdown]
# ### Connect to db

# %%
conn = psycopg2.connect(host="localhost",
                        database="{}_{}".format(dataname,index), 
                        user="holocleanuser", 
                        password="abcd1234")

# %%
def query_df(q, value = []):
    if len(value) != 0:
        df = pd.read_sql_query(q, conn, params=value)
    else:
        df = pd.read_sql_query(q, conn)
    return df

# %%
def table_lists():
    df = query_df("""SELECT table_name FROM information_schema.tables
       WHERE table_schema = 'public'""")
    return df

# %%
table_lists()
# Out:
#          table_name
# 0    inf_values_idx
# 1           adult_1
# 2          dk_cells
# 3       cell_domain
# 4        pos_values
# 5        cell_distr
# 6    inf_values_dom
# 7  adult_1_repaired
# 8     adult_1_clean

# %%
df = query_df("select * from %s" % dataname)

# %%
df.head()
# Out:
#    _tid_  age workclass education  maritalstatus         occupation  \
# 0      0  <18   private      10th  never-married  machine-op-inspct
# 1      1  <18     _nan_      10th  never-married              _nan_
# 2      2  <18   private      11th  never-married              sales
# 3      3  <18   private      10th  never-married              sales
# 4      4  <18     _nan_      11th  never-married              _nan_
#
#     relationship   race     sex hoursperweek        country       income
# 0  not-in-family  white    male           40  united-states  lessthan50k
# 1      own-child  white    male           40  united-states  lessthan50k
# 2      own-child  white  female           25  united-states  lessthan50k
# 3      own-child  white  female        18-21  united-states  lessthan50k
# 4      own-child  white    male           40  united-states  lessthan50k

# %%
# get all attributes 
data = query_df("select * from {}".format(dataname))
attributes = data.columns.values[1:]
attributes
# Out:
# array(['age', 'workclass', 'education', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'sex', 'hoursperweek', 'country', 'income'],
#       dtype=object)

# %% [markdown]
# ### Total Errors

# %%
errors_template = Template('SELECT t1._tid_, t2._attribute_, t1.\"$attr\" as init, t2._value_ as gt '\
                            'FROM $init_table as t1, $grdt_table as t2 '\
                            'WHERE t1._tid_ = t2._tid_ '\
                              'AND t2._attribute_ = \'$attr\' '\
                              'AND t1.\"$attr\" != t2._value_')

# %%
def get_total_errors():
    all_error = []
    for attr in attributes:
        query = errors_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname,
                        attr=attr)
        df = query_df(query)
        all_error.append(df)
    return all_error

# %%
all_error = get_total_errors()

# %%
all_error = pd.concat(all_error, ignore_index=True)

# %%
all_error.head()
# Out:
#   _tid_ _attribute_   init     gt
# 0  4987         age  18-21  22-30
# 1  5683         age  18-21  22-30
# 2  6496         age  18-21  22-30
# 3  6983         age  18-21  22-30
# 4  8989         age  18-21  22-30

# %%
vid_template = Template("SELECT * from cell_domain where attribute = \'$attr\' and _tid_ = \'$tid\'")

# %%
query_df(vid_template.substitute(attr='income', tid=609))
# Out:
#    _cid_  _tid_  _vid_ attribute                                   domain  \
# 0   6709    609   4879    income  morethan50k|||lessthan50k|||lessthan5k0
#
#    domain_size  fixed  init_index   init_value   weak_label  weak_label_idx
# 0            3      0           2  lessthan5k0  lessthan5k0               2

# %%
df = query_df(vid_template.substitute(attr='income', tid=609))

# %%
df['domain'].values
# Out:
# array(['morethan50k|||lessthan50k|||lessthan5k0'], dtype=object)

# %%
query_df("SELECT t2.distribution from cell_domain as t1, cell_distr as t2 where t1._vid_ = 4879 and t2._vid_ = t1._vid_ ").values
# Out:
# array([['{0.10650698,0.10650698,0.78698605}']], dtype=object)

# %%
init_count = all_error.shape[0]
init_count
# Out:
# 1062

# %% [markdown]
# ### Total Repair

# %%
query = "SELECT t1._tid_, t1.attribute, t1.init_value as init, t2.rv_value as repair " \
                 "FROM %s as t1, %s as t2 " \
                 "WHERE t1._tid_ = t2._tid_ " \
                   "AND t1.attribute = t2.attribute " \
                   "AND t1.init_value != t2.rv_value"\
                %('cell_domain', 'inf_values_dom')
all_repair = query_df(query)

# %%
all_repair.head()
# Out:
#    _tid_  attribute       init         repair
# 0      8    country     mexico  united-states
# 1     25    country     mexico  united-states
# 2     28    country   columbia  united-states
# 3     29  workclass  local-gov        private
# 4     38    country     poland  united-states

# %%
total_repair_init_count = all_repair.shape[0]
total_repair_init_count
# Out:
# 29093

# %%
query = "SELECT t1._tid_, t1.attribute, t1.init_value as init, t2.rv_value as repair " \
         "FROM %s as t1, %s as t2, %s as t3 " \
         "WHERE t1._tid_ = t2._tid_ " \
           "AND t1.attribute = t2.attribute " \
           "AND t1.init_value != t2.rv_value " \
           "AND t1._tid_ = t3._tid_ " \
           "AND t1.attribute = t3._attribute_"\
        %('cell_domain', 'inf_values_dom', '%s_clean'%dataname)
repair_gt = query_df(query)

# %%
repair_gt.head()
# Out:
#    _tid_  attribute       init         repair
# 0      8    country     mexico  united-states
# 1     25    country     mexico  united-states
# 2     28    country   columbia  united-states
# 3     29  workclass  local-gov        private
# 4     38    country     poland  united-states

# %%
repair_gt_init_count = repair_gt.shape[0]
repair_gt_init_count
# Out:
# 29093

# %% [markdown]
# ### Correct Repair

# %%
correct_repairs_template = Template('SELECT errors._tid_, errors._attribute_, '\
                            ' errors.init, errors._value_ as gt, repairs.rv_value as repair FROM'\
                            '(SELECT t2._tid_, t2._attribute_, t2._value_, t1.\"$attr\" as init '\
                             'FROM $init_table as t1, $grdt_table as t2 '\
                             'WHERE t1._tid_ = t2._tid_ '\
                               'AND t2._attribute_ = \'$attr\' '\
                               'AND t1.\"$attr\" != t2._value_ ) as errors, $inf_dom as repairs '\
                              'WHERE errors._tid_ = repairs._tid_ '\
                                'AND errors._attribute_ = repairs.attribute '\
                                'AND errors._value_ = repairs.rv_value')

# %%
def get_total_repair():
    all_rp = []
    for attr in attributes:
        query = correct_repairs_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname, 
                                            inf_dom = 'inf_values_dom', attr=attr)
        df = query_df(query)
        all_rp.append(df)
    return all_rp

# %%
all_repair_gt = get_total_repair()

# %%
all_repair_gt = pd.concat(all_repair_gt, ignore_index=True)

# %%
all_repair_gt.head(30)
# Out:
# Empty DataFrame
# Columns: [_tid_, _attribute_, init, gt, repair]
# Index: []

# %%
all_repair_gt.shape[0]
# Out:
# 0

# %% [markdown]
# ### wrong repair correctly detected

# %%
wrong_repairs_template = Template('SELECT errors._tid_, errors._attribute_, '\
                            ' errors.init, errors._value_ as gt, repairs.rv_value as repair FROM'\
                            '(SELECT t2._tid_, t2._attribute_, t2._value_, t1.\"$attr\" as init '\
                             'FROM $init_table as t1, $grdt_table as t2 '\
                             'WHERE t1._tid_ = t2._tid_ '\
                               'AND t2._attribute_ = \'$attr\' '\
                               'AND t1.\"$attr\" != t2._value_ ) as errors, $inf_dom as repairs '\
                              'WHERE errors._tid_ = repairs._tid_ '\
                                'AND errors._attribute_ = repairs.attribute '\
                                'AND errors._value_ <> repairs.rv_value')

# %%
def get_total_wrong_repair():
    all_rp = []
    for attr in attributes:
        query = wrong_repairs_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname, 
                                            inf_dom = 'inf_values_dom', attr=attr)
        df = query_df(query)
        all_rp.append(df)
    return all_rp

# %%
wrong_repair_gt = get_total_wrong_repair()

# %%
wrong_repair_gt = pd.concat(wrong_repair_gt, ignore_index=True)

# %%
wrong_repair_gt
# Out:
#       _tid_ _attribute_            init           gt          repair
# 0      4987         age           18-21        22-30           18-21
# 1      7521         age           18-21        22-30           18-21
# 2     12308         age           18-21        22-30           18-21
# 3     13059         age           18-21        22-30           18-21
# 4     13769         age           18-21        22-30           18-21
# 5     14557         age           18-21        22-30           18-21
# 6     18898         age           18-21        31-50           18-21
# 7     19894         age           18-21        31-50           18-21
# 8     20535         age           18-21        31-50           18-21
# 9     21160         age           18-21        31-50           18-21
# 10    23807         age           18-21        31-50           18-21
# 11    26561         age           18-21        31-50           18-21
# 12    29001         age           18-21        31-50           18-21
# 13    31047         age           18-21        31-50           18-21
# 14    32801         age           18-21        31-50           18-21
# 15    35963         age           18-21        31-50           18-21
# 16    48794         age           18-21          >50           18-21
# 17    53829         age           18-21        22-30           18-21
# 18    54525         age           18-21        22-30           18-21
# 19    55338         age           18-21        22-30           18-21
# 20    61150         age           18-21        22-30           18-21
# 21    61901         age           18-21        22-30           18-21
# 22    62611         age           18-21        22-30           18-21
# 23    66131         age           18-21        31-50           18-21
# 24    68897         age           18-21        31-50           18-21
# 25    69377         age           18-21        31-50           18-21
# 26    70002         age           18-21        31-50           18-21
# 27    72649         age           18-21        31-50           18-21
# 28    75403         age           18-21        31-50           18-21
# 29    77843         age           18-21        31-50           18-21
# ...     ...         ...             ...          ...             ...
# 1032  52626      income     lessthan5k0  lessthan50k     lessthan5k0
# 1033  52628      income      lesthan50k  lessthan50k      lesthan50k
# 1034  52631      income    lessthan5v0k  lessthan50k    lessthan5v0k
# 1035  52647      income     lsesthan50k  lessthan50k     lsesthan50k
# 1036  52666      income    lesstbhan50k  lessthan50k    lesstbhan50k
# 1037  52677      income     lessthan05k  lessthan50k     lessthan05k
# 1038  52688      income     lessthan05k  lessthan50k     lessthan05k
# 1039  52717      income    lesrsthan50k  lessthan50k    lesrsthan50k
# 1040  52802      income      lessthan5k  lessthan50k      lessthan5k
# 1041  52810      income     elssthan50k  lessthan50k     elssthan50k
# 1042  52849      income     lessthan05k  lessthan50k     lessthan05k
# 1043  52864      income    levssthan50k  lessthan50k    levssthan50k
# 1044  52903      income    lesswthan50k  lessthan50k    lesswthan50k
# 1045  52904      income     lsesthan50k  lessthan50k     lsesthan50k
# 1046  52910      income     lessthan05k  lessthan50k     lessthan05k
# 1047  52971      income      lessthan0k  lessthan50k      lessthan0k
# 1048  52973      income      lesshan50k  lessthan50k      lesshan50k
# 1049  53002      income    lesslthan50k  lessthan50k    lesslthan50k
# 1050  53031      income    lesskthan50k  lessthan50k    lesskthan50k
# 1051  53065      income      lssthan50k  lessthan50k      lssthan50k
# 1052  53102      income     lessthan5k0  lessthan50k     lessthan5k0
# 1053  53105      income      essthan50k  lessthan50k      essthan50k
# 1054  53130      income     lesstha5n0k  lessthan50k     lesstha5n0k
# 1055  53187      income     elssthan50k  lessthan50k     elssthan50k
# 1056  53242      income    lessthgan50k  lessthan50k    lessthgan50k
# 1057  53263      income      lesstan50k  lessthan50k      lesstan50k
# 1058  53307      income      essthan50k  lessthan50k      essthan50k
# 1059  53364      income    lesstehan50k  lessthan50k    lesstehan50k
# 1060  53393      income      lessthan5k  lessthan50k      lessthan5k
# 1061  53418      income  lessthan50k***  lessthan50k  lessthan50k***
#
# [1062 rows x 5 columns]

# %% [markdown]
# ### Detected Errors

# %%
query = "SELECT t1._tid_, t1.init_value as init, t2._value_ as gt " \
        "FROM %s as t1, %s as t2, %s as t3 " \
        "WHERE t1._tid_ = t2._tid_ AND t1._cid_ = t3._cid_ " \
        "AND t1.attribute = t2._attribute_ " \
        "AND t1.init_value != t2._value_" \
        % ('cell_domain', '%s_clean'%dataname, 'dk_cells')

# %%
init_error = query_df(query)

# %%
init_error.shape[0]
# Out:
# 1062

# %%
init_error.head(10)
# Out:
#    _tid_            init           gt
# 0    657  lessthan50k***  lessthan50k
# 1    713  lessthan50k***  lessthan50k
# 2    745    lessthapn50k  lessthan50k
# 3    828    lessthans50k  lessthan50k
# 4   1036     lessthna50k  lessthan50k
# 5   1103      lesshan50k  lessthan50k
# 6   1230     lestshan50k  lessthan50k
# 7   1567    lesstwhan50k  lessthan50k
# 8   1670     lesstha5n0k  lessthan50k
# 9   1747    lessthanr50k  lessthan50k

# %%
query_df("select fixed, init_value, weak_label, rv_value, _value_ from cell_domain t1, inf_values_dom t2, adult_1_clean t3 where t1._tid_ = t3._tid_ and t1.attribute = t3._attribute_ and t1._tid_ = t2._tid_ and t1.attribute = t2.attribute and fixed = 1 and weak_label = rv_value and rv_value != _value_;")
# Out:
#       fixed          init_value     weak_label       rv_value  \
# 0         1            columbia  united-states  united-states
# 1         1              poland  united-states  united-states
# 2         1         puerto-rico  united-states  united-states
# 3         1        never-worked        private        private
# 4         1         philippines  united-states  united-states
# 5         1           guatemala  united-states  united-states
# 6         1             england  united-states  united-states
# 7         1             england  united-states  united-states
# 8         1         philippines  united-states  united-states
# 9         1               other          white          white
# 10        1         puerto-rico  united-states  united-states
# 11        1              canada  united-states  united-states
# 12        1     trinadad&tobago  united-states  united-states
# 13        1               haiti  united-states  united-states
# 14        1         el-salvador  united-states  united-states
# 15        1              poland  united-states  united-states
# 16        1             england  united-states  united-states
# 17        1                peru  united-states  united-states
# 18        1         el-salvador  united-states  united-states
# 19        1              canada  united-states  united-states
# 20        1                peru  united-states  united-states
# 21        1               india  united-states  united-states
# 22        1         puerto-rico  united-states  united-states
# 23        1               haiti  united-states  united-states
# 24        1         el-salvador  united-states  united-states
# 25        1             england  united-states  united-states
# 26        1             england  united-states  united-states
# 27        1              canada  united-states  united-states
# 28        1                peru  united-states  united-states
# 29        1               other          white          white
# ...     ...                 ...            ...            ...
# 6268      1         philippines  united-states  united-states
# 6269      1               china  united-states  united-states
# 6270      1              canada  united-states  united-states
# 6271      1              canada  united-states  united-states
# 6272      1             england  united-states  united-states
# 6273      1               italy  united-states  united-states
# 6274      1               other          white          white
# 6275      1                cuba  united-states  united-states
# 6276      1           nicaragua  united-states  united-states
# 6277      1               south  united-states  united-states
# 6278      1  dominican-republic  united-states  united-states
# 6279      1            portugal  united-states  united-states
# 6280      1         el-salvador  united-states  united-states
# 6281      1              poland  united-states  united-states
# 6282      1              canada  united-states  united-states
# 6283      1         philippines  united-states  united-states
# 6284      1              canada  united-states  united-states
# 6285      1            portugal  united-states  united-states
# 6286      1              greece  united-states  united-states
# 6287      1              poland  united-states  united-states
# 6288      1             hungary  united-states  united-states
# 6289      1                cuba  united-states  united-states
# 6290      1             england  united-states  united-states
# 6291      1              poland  united-states  united-states
# 6292      1               south  united-states  united-states
# 6293      1         puerto-rico  united-states  united-states
# 6294      1             ecuador  united-states  united-states
# 6295      1               south  united-states  united-states
# 6296      1         philippines  united-states  united-states
# 6297      1             england  united-states  united-states
#
#                  _value_
# 0               columbia
# 1                 poland
# 2            puerto-rico
# 3           never-worked
# 4            philippines
# 5              guatemala
# 6                england
# 7                england
# 8            philippines
# 9                  other
# 10           puerto-rico
# 11                canada
# 12       trinadad&tobago
# 13                 haiti
# 14           el-salvador
# 15                poland
# 16               england
# 17                  peru
# 18           el-salvador
# 19                canada
# 20                  peru
# 21                 india
# 22           puerto-rico
# 23                 haiti
# 24           el-salvador
# 25               england
# 26               england
# 27                canada
# 28                  peru
# 29                 other
# ...                  ...
# 6268         philippines
# 6269               china
# 6270              canada
# 6271              canada
# 6272             england
# 6273               italy
# 6274               other
# 6275                cuba
# 6276           nicaragua
# 6277               south
# 6278  dominican-republic
# 6279            portugal
# 6280         el-salvador
# 6281              poland
# 6282              canada
# 6283         philippines
# 6284              canada
# 6285            portugal
# 6286              greece
# 6287              poland
# 6288             hungary
# 6289                cuba
# 6290             england
# 6291              poland
# 6292               south
# 6293         puerto-rico
# 6294             ecuador
# 6295               south
# 6296         philippines
# 6297             england
#
# [6298 rows x 5 columns]

# %%
query_df("select fixed, init_value, weak_label from cell_domain where fixed = 2 and init_value = weak_label;")
# Out:
#         fixed     init_value     weak_label
# 0           2        private        private
# 1           2  united-states  united-states
# 2           2          white          white
# 3           2  united-states  united-states
# 4           2  united-states  united-states
# 5           2  united-states  united-states
# 6           2  united-states  united-states
# 7           2  united-states  united-states
# 8           2  united-states  united-states
# 9           2          white          white
# 10          2  united-states  united-states
# 11          2        private        private
# 12          2  united-states  united-states
# 13          2  united-states  united-states
# 14          2  united-states  united-states
# 15          2  united-states  united-states
# 16          2  united-states  united-states
# 17          2          white          white
# 18          2        private        private
# 19          2  united-states  united-states
# 20          2        private        private
# 21          2  united-states  united-states
# 22          2  united-states  united-states
# 23          2  united-states  united-states
# 24          2        private        private
# 25          2  united-states  united-states
# 26          2        private        private
# 27          2  united-states  united-states
# 28          2  united-states  united-states
# 29          2  united-states  united-states
# ...       ...            ...            ...
# 170884      2          white          white
# 170885      2  united-states  united-states
# 170886      2  united-states  united-states
# 170887      2          white          white
# 170888      2  united-states  united-states
# 170889      2  united-states  united-states
# 170890      2        private        private
# 170891      2  united-states  united-states
# 170892      2          white          white
# 170893      2        private        private
# 170894      2  united-states  united-states
# 170895      2          white          white
# 170896      2  united-states  united-states
# 170897      2          white          white
# 170898      2  united-states  united-states
# 170899      2          white          white
# 170900      2  united-states  united-states
# 170901      2  united-states  united-states
# 170902      2          white          white
# 170903      2  united-states  united-states
# 170904      2          white          white
# 170905      2        private        private
# 170906      2  united-states  united-states
# 170907      2          white          white
# 170908      2  united-states  united-states
# 170909      2          white          white
# 170910      2        private        private
# 170911      2  united-states  united-states
# 170912      2  united-states  united-states
# 170913      2          white          white
#
# [170914 rows x 3 columns]
